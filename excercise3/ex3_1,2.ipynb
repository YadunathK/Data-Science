# %%
import matplotlib.pyplot as plt
import numpy as np

xpoints = np.array([1, 2, 6, 18])
ypoints = np.array([3, 10, 12, 20])

plt.plot(xpoints, ypoints,'o:b',mec='g')
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

xpoints = np.array([12,14,16,18,20,22,24])
ypoints = np.array([100,200,250,400,300,450,500])

plt.plot(xpoints, ypoints,'g')
plt.xlabel('Tempreture in degree celsius')
plt.ylabel('sales')
plt.show()
